# %%
import json

data = {
    "name": "Riya",
    "age": 20,
    "subjects": ["Math", "CS", "Physics"],
    "marks": {
        "math": 90,
        "cs": 94
    }
}

with open("student.json", "w") as f:
    json.dump(data, f, indent=4)

print("File created!")
# Out:
# File created!

# %%
# !ls -l
# Out:
# total 8
# drwxr-xr-x 1 root root 4096 Nov 20 14:30 sample_data
# -rw-r--r-- 1 root root  169 Dec  2 18:47 student.json

# %%
from google.colab import files
files.download("student.json")

# %%
# !cat student.json
# Out:
# {
#     "name": "Riya",
#     "age": 20,
#     "subjects": [
#         "Math",
#         "CS",
#         "Physics"
#     ],
#     "marks": {
#         "math": 90,
#         "cs": 94
#     }
# }
